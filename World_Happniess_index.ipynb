# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go
from wordcloud import WordCloud
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df_2015 = pd.read_csv('/content/2015.csv')
df_2016 = pd.read_csv('/content/2016.csv')
df_2017 = pd.read_csv('/content/2017.csv')
df_2018 = pd.read_csv('/content/2018.csv')
df_2019 = pd.read_csv('/content/2019.csv')
df_2020 = pd.read_csv('/content/2020.csv')
df_2021 = pd.read_csv('/content/2021.csv')

# %%
df_2015.head()
# Out:
#        Country          Region  ...  Generosity  Dystopia Residual
# 0  Switzerland  Western Europe  ...     0.29678            2.51738
# 1      Iceland  Western Europe  ...     0.43630            2.70201
# 2      Denmark  Western Europe  ...     0.34139            2.49204
# 3       Norway  Western Europe  ...     0.34699            2.46531
# 4       Canada   North America  ...     0.45811            2.45176
#
# [5 rows x 12 columns]

# %%
df_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df_2015.tail()
# Out:
#      Country                           Region  ...  Generosity  Dystopia Residual
# 153   Rwanda               Sub-Saharan Africa  ...     0.22628            0.67042
# 154    Benin               Sub-Saharan Africa  ...     0.18260            1.63328
# 155    Syria  Middle East and Northern Africa  ...     0.47179            0.32858
# 156  Burundi               Sub-Saharan Africa  ...     0.19727            1.83302
# 157     Togo               Sub-Saharan Africa  ...     0.16681            1.56726
#
# [5 rows x 12 columns]

# %% [markdown]
# Country --> Name of the country.
#
# Region --> Region the country belongs to.
#
# Happiness Rank --> Rank of the country based on the Happiness Score.
#
# Happiness Score --> A metric measured in 2015 by asking the sampled people the question: "How would you rate your happiness on a scale of 0 to 10 where 10 is the happiest."
#
# Standard Error --> The standard error of the happiness score.
#
# Economy (GDP per Capita) --> The extent to which GDP contributes to the calculation of the Happiness Score.
#
# Family --> The extent to which Family contributes to the calculation of the Happiness Score
#
# Health (Life Expectancy) --> The extent to which Life expectancy contributed to the calculation of the Happiness Score
#
# Freedom --> The extent to which Freedom contributed to the calculation of the Happiness Score.
#
# Trust (Government Corruption) --> The extent to which Perception of Corruption contributes to Happiness Score.
#
# Generosity --> The extent to which Generosity contributed to the calculation of the Happiness Score.
#
# Dystopia Residual --> The extent to which Dystopia Residual contributed to the calculation of the Happiness Score.

# %%
High_GDP = df_2015.groupby('Country')['Economy (GDP per Capita)'].max().sort_values(ascending = False).reset_index().head(10)
Family = df_2015.groupby('Country')['Family'].max().sort_values(ascending = False).reset_index().head(10)
corruptionfree = df_2015.groupby('Country')['Trust (Government Corruption)'].max().sort_values(ascending = False).reset_index().head(10)
Health = df_2015.groupby('Country')['Health (Life Expectancy)'].max().sort_values(ascending = False).reset_index().head(10)
Freedom = df_2015.groupby('Country')['Freedom'].max().sort_values(ascending = False).reset_index().head(10)
Generosity = df_2015.groupby('Country')['Generosity'].max().sort_values(ascending = False).reset_index().head(10)
DystopiaResidual = df_2015.groupby('Country')['Dystopia Residual'].max().sort_values(ascending = False).reset_index().head(10)

# %%
plt.figure(figsize=(18,15))

plt.subplots_adjust(wspace = .5)
plt.subplot(4,2,1)
sns.barplot(x='Family', y='Country', data = Family)

plt.subplot(4,2,2)
sns.barplot(x='Economy (GDP per Capita)', y= 'Country', data = High_GDP)

plt.subplot(4,2,3)
sns.barplot(x='Trust (Government Corruption)', y= 'Country', data = corruptionfree)

plt.subplot(4,2,4)
sns.barplot(x='Health (Life Expectancy)', y= 'Country', data = Health)


plt.subplot(4,2,5)
sns.barplot(x='Freedom', y= 'Country', data = Freedom)

plt.subplot(4,2,6)
sns.barplot(x='Generosity', y= 'Country', data = Generosity)

plt.subplot(4,2,7)
sns.barplot(x='Dystopia Residual', y= 'Country', data = DystopiaResidual)

# %%
df_2016.head()
# Out:
#        Country          Region  ...  Generosity  Dystopia Residual
# 0      Denmark  Western Europe  ...     0.36171            2.73939
# 1  Switzerland  Western Europe  ...     0.28083            2.69463
# 2      Iceland  Western Europe  ...     0.47678            2.83137
# 3       Norway  Western Europe  ...     0.37895            2.66465
# 4      Finland  Western Europe  ...     0.25492            2.82596
#
# [5 rows x 13 columns]

# %%
High_GDP = df_2016.groupby('Country')['Economy (GDP per Capita)'].max().sort_values(ascending = False).reset_index().head(10)
Family = df_2016.groupby('Country')['Family'].max().sort_values(ascending = False).reset_index().head(10)
corruptionfree = df_2016.groupby('Country')['Trust (Government Corruption)'].max().sort_values(ascending = False).reset_index().head(10)
Health = df_2016.groupby('Country')['Health (Life Expectancy)'].max().sort_values(ascending = False).reset_index().head(10)
Freedom = df_2016.groupby('Country')['Freedom'].max().sort_values(ascending = False).reset_index().head(10)
Generosity = df_2016.groupby('Country')['Generosity'].max().sort_values(ascending = False).reset_index().head(10)
DystopiaResidual = df_2016.groupby('Country')['Dystopia Residual'].max().sort_values(ascending = False).reset_index().head(10)

# %%
plt.figure(figsize=(18,15))

plt.subplots_adjust(wspace = .5)
plt.subplot(4,2,1)
sns.barplot(x='Family', y='Country', data = Family)

plt.subplot(4,2,2)
sns.barplot(x='Economy (GDP per Capita)', y= 'Country', data = High_GDP)

plt.subplot(4,2,3)
sns.barplot(x='Trust (Government Corruption)', y= 'Country', data = corruptionfree)

plt.subplot(4,2,4)
sns.barplot(x='Health (Life Expectancy)', y= 'Country', data = Health)


plt.subplot(4,2,5)
sns.barplot(x='Freedom', y= 'Country', data = Freedom)

plt.subplot(4,2,6)
sns.barplot(x='Generosity', y= 'Country', data = Generosity)

plt.subplot(4,2,7)
sns.barplot(x='Dystopia Residual', y= 'Country', data = DystopiaResidual)

# %%
df_2017.head()
# Out:
#        Country  ...  Dystopia.Residual
# 0       Norway  ...           2.277027
# 1      Denmark  ...           2.313707
# 2      Iceland  ...           2.322715
# 3  Switzerland  ...           2.276716
# 4      Finland  ...           2.430182
#
# [5 rows x 12 columns]

# %%
df_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
High_GDP = df_2017.groupby('Country')['Economy..GDP.per.Capita.'].max().sort_values(ascending = False).reset_index().head(10)
Family = df_2017.groupby('Country')['Family'].max().sort_values(ascending = False).reset_index().head(10)
corruptionfree = df_2017.groupby('Country')['Trust..Government.Corruption.'].max().sort_values(ascending = False).reset_index().head(10)
Health = df_2017.groupby('Country')['Health..Life.Expectancy.'].max().sort_values(ascending = False).reset_index().head(10)
Freedom = df_2017.groupby('Country')['Freedom'].max().sort_values(ascending = False).reset_index().head(10)
Generosity = df_2017.groupby('Country')['Generosity'].max().sort_values(ascending = False).reset_index().head(10)
DystopiaResidual = df_2017.groupby('Country')['Dystopia.Residual'].max().sort_values(ascending = False).reset_index().head(10)

# %%
plt.figure(figsize=(18,15))

plt.subplots_adjust(wspace = .5)
plt.subplot(4,2,1)
sns.barplot(x='Family', y='Country', data = Family)

plt.subplot(4,2,2)
sns.barplot(x='Economy..GDP.per.Capita.', y= 'Country', data = High_GDP)

plt.subplot(4,2,3)
sns.barplot(x='Trust..Government.Corruption.', y= 'Country', data = corruptionfree)

plt.subplot(4,2,4)
sns.barplot(x='Health..Life.Expectancy.', y= 'Country', data = Health)


plt.subplot(4,2,5)
sns.barplot(x='Freedom', y= 'Country', data = Freedom)

plt.subplot(4,2,6)
sns.barplot(x='Generosity', y= 'Country', data = Generosity)

plt.subplot(4,2,7)
sns.barplot(x='Dystopia.Residual', y= 'Country', data = DystopiaResidual)

# %%
df_2018.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.202                      0.393
# 1             2            Norway  ...       0.286                      0.340
# 2             3           Denmark  ...       0.284                      0.408
# 3             4           Iceland  ...       0.353                      0.138
# 4             5       Switzerland  ...       0.256                      0.357
#
# [5 rows x 9 columns]

# %%
df_2018[df_2018.isna().any(axis=1)]
# Out:
#     Overall rank     Country or region  ...  Generosity  Perceptions of corruption
# 19            20  United Arab Emirates  ...       0.186                        NaN
#
# [1 rows x 9 columns]

# %%
df_2018=df_2018.fillna(0)

# %%
High_GDP = df_2018.groupby('Country or region')['GDP per capita'].max().sort_values(ascending = False).reset_index().head(10)
Social_support = df_2018.groupby('Country or region')['Social support'].max().sort_values(ascending = False).reset_index().head(10)
corruptionfree = df_2018.groupby('Country or region')['Perceptions of corruption'].max().sort_values(ascending = False).reset_index().head(10)
Health = df_2018.groupby('Country or region')['Healthy life expectancy'].max().sort_values(ascending = False).reset_index().head(10)
Freedom = df_2018.groupby('Country or region')['Freedom to make life choices'].max().sort_values(ascending = False).reset_index().head(10)
Generosity = df_2018.groupby('Country or region')['Generosity'].max().sort_values(ascending = False).reset_index().head(10)

# %%
plt.figure(figsize=(18,15))

plt.subplots_adjust(wspace = .5)
plt.subplot(3,2,1)
sns.barplot(x='Social support', y='Country or region', data = Social_support)

plt.subplot(3,2,2)
sns.barplot(x='GDP per capita', y= 'Country or region', data = High_GDP)

plt.subplot(3,2,3)
sns.barplot(x='Perceptions of corruption', y= 'Country or region', data = corruptionfree)

plt.subplot(3,2,4)
sns.barplot(x='Healthy life expectancy', y= 'Country or region', data = Health)


plt.subplot(3,2,5)
sns.barplot(x='Freedom to make life choices', y= 'Country or region', data = Freedom)

plt.subplot(3,2,6)
sns.barplot(x='Generosity', y= 'Country or region', data = Generosity)

# %%
df_2019.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
High_GDP = df_2019.groupby('Country or region')['GDP per capita'].max().sort_values(ascending = False).reset_index().head(10)
Social_support = df_2019.groupby('Country or region')['Social support'].max().sort_values(ascending = False).reset_index().head(10)
corruptionfree = df_2019.groupby('Country or region')['Perceptions of corruption'].max().sort_values(ascending = False).reset_index().head(10)
Health = df_2019.groupby('Country or region')['Healthy life expectancy'].max().sort_values(ascending = False).reset_index().head(10)
Freedom = df_2019.groupby('Country or region')['Freedom to make life choices'].max().sort_values(ascending = False).reset_index().head(10)
Generosity = df_2019.groupby('Country or region')['Generosity'].max().sort_values(ascending = False).reset_index().head(10)

# %%
plt.figure(figsize=(18,15))

plt.subplots_adjust(wspace = .5)
plt.subplot(3,2,1)
sns.barplot(x='Social support', y='Country or region', data = Social_support)

plt.subplot(3,2,2)
sns.barplot(x='GDP per capita', y= 'Country or region', data = High_GDP)

plt.subplot(3,2,3)
sns.barplot(x='Perceptions of corruption', y= 'Country or region', data = corruptionfree)

plt.subplot(3,2,4)
sns.barplot(x='Healthy life expectancy', y= 'Country or region', data = Health)


plt.subplot(3,2,5)
sns.barplot(x='Freedom to make life choices', y= 'Country or region', data = Freedom)

plt.subplot(3,2,6)
sns.barplot(x='Generosity', y= 'Country or region', data = Generosity)

# %%
df_2020.head()
# Out:
#   Country name  ... Dystopia + residual
# 0      Finland  ...            2.762835
# 1      Denmark  ...            2.432741
# 2  Switzerland  ...            2.350267
# 3      Iceland  ...            2.460688
# 4       Norway  ...            2.168266
#
# [5 rows x 20 columns]

# %%
df_2020.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
High_GDP = df_2020.groupby('Country name')['Explained by: Log GDP per capita'].max().sort_values(ascending=False).reset_index().head(10)
Social_support = df_2020.groupby('Country name')['Explained by: Social support'].max().sort_values(ascending=False).reset_index().head(10)
Health = df_2020.groupby('Country name')['Explained by: Healthy life expectancy'].max().sort_values(ascending=False).reset_index().head(10)
corruptionfree = df_2020.groupby('Country name')['Explained by: Perceptions of corruption'].max().sort_values(ascending=False).reset_index().head(10)
Freedom = df_2020.groupby('Country name')['Explained by: Freedom to make life choices'].max().sort_values(ascending=False).reset_index().head(10)
Generosity = df_2020.groupby('Country name')['Explained by: Generosity'].max().sort_values(ascending=False).reset_index().head(10)
Dystopia = df_2020.groupby('Country name')['Dystopia + residual'].max().sort_values(ascending = False).reset_index().head(10)

# %%
plt.figure(figsize=(18,15))
plt.subplots_adjust(wspace = .5)

plt.subplot(4,2,1)
sns.barplot(x='Explained by: Social support', y='Country name', data = Social_support)

plt.subplot(4,2,2)
sns.barplot(x='Explained by: Log GDP per capita', y= 'Country name', data = High_GDP)

plt.subplot(4,2,3)
sns.barplot(x='Explained by: Perceptions of corruption', y= 'Country name', data = corruptionfree)

plt.subplot(4,2,4)
sns.barplot(x='Explained by: Healthy life expectancy', y= 'Country name', data = Health)


plt.subplot(4,2,5)
sns.barplot(x='Explained by: Freedom to make life choices', y= 'Country name', data = Freedom)

plt.subplot(4,2,6)
sns.barplot(x='Explained by: Generosity', y= 'Country name', data = Generosity)

plt.subplot(4,2,7)
sns.barplot(x='Dystopia + residual', y= 'Country name', data = Dystopia)

# %%
df_2021.head()
# Out:
#   Country name  ... Dystopia + residual
# 0      Finland  ...               3.253
# 1      Denmark  ...               2.868
# 2  Switzerland  ...               2.839
# 3      Iceland  ...               2.967
# 4  Netherlands  ...               2.798
#
# [5 rows x 20 columns]

# %%
High_GDP = df_2021.groupby('Country name')['Explained by: Log GDP per capita'].max().sort_values(ascending=False).reset_index().head(10)
Social_support = df_2021.groupby('Country name')['Explained by: Social support'].max().sort_values(ascending=False).reset_index().head(10)
Health = df_2021.groupby('Country name')['Explained by: Healthy life expectancy'].max().sort_values(ascending=False).reset_index().head(10)
corruptionfree = df_2021.groupby('Country name')['Explained by: Perceptions of corruption'].max().sort_values(ascending=False).reset_index().head(10)
Freedom = df_2021.groupby('Country name')['Explained by: Freedom to make life choices'].max().sort_values(ascending=False).reset_index().head(10)
Generosity = df_2021.groupby('Country name')['Explained by: Generosity'].max().sort_values(ascending=False).reset_index().head(10)
Dystopia = df_2021.groupby('Country name')['Dystopia + residual'].max().sort_values(ascending = False).reset_index().head(10)

# %%
plt.figure(figsize=(18,15))
plt.subplots_adjust(wspace = .5)

plt.subplot(4,2,1)
sns.barplot(x='Explained by: Social support', y='Country name', data = Social_support)

plt.subplot(4,2,2)
sns.barplot(x='Explained by: Log GDP per capita', y= 'Country name', data = High_GDP)

plt.subplot(4,2,3)
sns.barplot(x='Explained by: Perceptions of corruption', y= 'Country name', data = corruptionfree)

plt.subplot(4,2,4)
sns.barplot(x='Explained by: Healthy life expectancy', y= 'Country name', data = Health)


plt.subplot(4,2,5)
sns.barplot(x='Explained by: Freedom to make life choices', y= 'Country name', data = Freedom)

plt.subplot(4,2,6)
sns.barplot(x='Explained by: Generosity', y= 'Country name', data = Generosity)

plt.subplot(4,2,7)
sns.barplot(x='Dystopia + residual', y= 'Country name', data = Dystopia)

# %%
WHR= df_2021.copy()
WHR.set_index('Country name', inplace=True)

# %%
WHR[['Explained by: Log GDP per capita', 'Explained by: Social support','Explained by: Healthy life expectancy', 'Explained by: Freedom to make life choices', 'Explained by: Generosity', 'Explained by: Perceptions of corruption', 'Dystopia + residual']].head(20).plot(kind='barh',
                                                                xticks=np.arange(9), stacked=True, figsize= (10, 10))

plt.xlabel("Ladder score")
plt.title('Happiness Score of the top 10 Countries')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
year_2020 = df_2020.drop(['Ladder score in Dystopia','Logged GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity',
                 'Perceptions of corruption','upperwhisker', 'lowerwhisker', 'Country name','Standard error of ladder score', 'Ladder score','Regional indicator'],axis = 1)

# %%
year_2020.columns
# Out:
# Index(['Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
year_2020 = year_2020.rename(columns = {'Explained by: Log GDP per capita': 'GDP', 'Explained by: Social support': 'socio-support', 'Explained by: Healthy life expectancy':'Health', 
'Explained by: Freedom to make life choices':'Life_choice', 'Explained by: Generosity':'Generosity', 'Explained by: Perceptions of corruption':'corruption', 'Dystopia + residual':'Dystopia'}, inplace = False)

# %%
sns.pairplot(year_2020)

# %%
sns.pairplot(df_2015)

# %%
year_2021 = df_2021.drop(['Ladder score in Dystopia','Logged GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity',
                 'Perceptions of corruption','upperwhisker', 'lowerwhisker', 'Country name','Standard error of ladder score','Regional indicator'],axis = 1)

# %%
year_2021 = year_2021.rename(columns = {'Explained by: Log GDP per capita': 'GDP', 'Explained by: Social support': 'socio-support', 'Explained by: Healthy life expectancy':'Health', 
'Explained by: Freedom to make life choices':'Life_choice', 'Explained by: Generosity':'Generosity', 'Explained by: Perceptions of corruption':'corruption', 'Dystopia + residual':'Dystopia'}, inplace = False)

# %%
sns.pairplot(year_2021)

# %%
plt.figure(figsize=(18,15))
plt.subplots_adjust(wspace = .5)

plt.subplot(4,2,1)
sns.scatterplot(data = df_2021, x='Explained by: Social support', y='Ladder score', color="#FE4365")

plt.subplot(4,2,2)
sns.scatterplot(x='Explained by: Log GDP per capita', y= 'Ladder score', data = df_2021)

plt.subplot(4,2,3)
sns.scatterplot(x='Explained by: Perceptions of corruption', y= 'Ladder score', data = df_2021, color="#FE4365")

plt.subplot(4,2,4)
sns.scatterplot(x='Explained by: Healthy life expectancy', y= 'Ladder score', data = df_2021, color="#FE4365")


plt.subplot(4,2,5)
sns.scatterplot(x='Explained by: Freedom to make life choices', y= 'Ladder score', data = df_2021)

plt.subplot(4,2,6)
sns.scatterplot(x='Explained by: Generosity', y= 'Ladder score', data = df_2021, color="#FE4365")

plt.subplot(4,2,7)
sns.scatterplot(x='Dystopia + residual', y= 'Ladder score', data = df_2021)
